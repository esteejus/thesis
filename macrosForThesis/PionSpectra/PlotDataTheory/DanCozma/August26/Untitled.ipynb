# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Sn132_piRatio_simulation.csv")
df
# Out:
#       x       sim1       sim2       sim3      sim4      sim5      sim6  \
# 0     5  10.227674  10.665990  10.887902  9.571806  9.412144  9.953488
# 1    15   9.108682   9.503226  10.043079  8.225290  8.433728  9.706246
# 2    25   8.215447   8.702717   9.558501  7.701429  7.756133  8.493236
# 3    35   7.454817   8.100926   8.808648  7.111784  7.385787  8.010162
# 4    45   6.612344   6.698565   7.107097  5.737951  5.938993  6.706826
# 5    55   5.269304   5.635863   5.779599  5.108824  5.273036  5.649824
# 6    65   4.493265   4.491409   4.768626  4.562948  4.348023  4.640716
# 7    75   4.036435   4.075127   4.098108  3.940778  3.951606  4.362226
# 8    85   3.645193   3.535125   3.587891  3.645270  3.585470  3.649050
# 9    95   3.288193   3.143240   3.019669  3.560191  3.260371  3.324004
# 10  105   2.864096   2.877095   2.657002  3.163073  3.152247  2.988315
# 11  115   2.754673   2.390261   2.542178  3.213511  3.013471  2.830558
# ...

# %%
my_colors = [(x/10.0, x/20.0, 0.75) for x in range(len(mydata))] # <-- Quick gradient example along the Red/Green dimensions.

# %%
fig, ax1 = plt.subplots()
x = df['x']
y1 = df['sim9']
y2 = df['exp']

print(y2)
print(x)
ax2 = ax1.twinx()

ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')
# Out:
# 0     38.72310
# 1     13.64400
# 2      8.23447
# 3      5.69706
# 4      5.35650
# 5      4.10288
# 6      4.05420
# 7      3.50052
# 8      3.21723
# 9      3.03436
# 10     2.87445
# 11     2.82240
# 12     2.61712
# 13     2.75384
# 14     2.54969
# 15     2.55573
# 16     2.75858
# 17     2.69063
# 18     2.28375
# 19     2.72452
# Name: exp, dtype: float64
# 0       5
# 1      15
# 2      25
# 3      35
# 4      45
# 5      55
# 6      65
# 7      75
# 8      85
# 9      95
# 10    105
# 11    115
# 12    125
# 13    135
# 14    145
# 15    155
# 16    170
# 17    190
# 18    220
# 19    270
# Name: x, dtype: int64

# %%
plt.show()
