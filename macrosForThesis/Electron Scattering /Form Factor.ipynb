# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.integrate import quad

# %%
hc = 197.327053
pi = np.pi
r0 = 6.0
a  = 1.0
p0 = .001
rmax =  15.0

def den (r):
    if r < rmax:
        return p0/(1.0 + np.exp( (r - r0)/a) )
    else:
        return 0.0
    
rho = np.vectorize(den)

# %%
x = np.linspace(0.0,15.0,1000)
y = rho(x)

plt.plot(x,y, '-' )

# %%
def form (q):
   # y,err = quad(lambda r:(4.0 * pi) * r * den(r) * np.sin(q*r/hc)/q/hc, 0.0, np.inf)
    return abs(quad(lambda r:(4.0 * pi) * r * hc * den(r) * np.sin(q*r/hc)/q, 0.0, np.inf)[0])

# %%
formv = np.vectorize(form)

# %%
x1 = np.linspace(10,1000.0,1000)
y1 = formv(x1)

# %%
plt.plot(x1,y1)
plt.yscale('log')
plt.ylim(1e-12,1e2)
# Out:
# (1e-12, 100.0)
